# %% [markdown]
# ## Import librairies

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import datetime

import scipy.stats as st
from scipy.stats import chi2_contingency
from scipy.stats import ks_2samp
from scipy.stats import kstest
from scipy.stats import f_oneway
from scipy.stats import wilcoxon

import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.pyplot import figure
# %matplotlib inline

# %%
#Gestion des options d'affichage 
pd.set_option('display.max_row',1000)
pd.set_option('display.max_columns',30)

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Customers

# %%
customers= pd.read_csv('customers.csv', sep=',')

# %%
customers.head()
# Out:
#   client_id sex  birth
# 0    c_4410   f   1967
# 1    c_7839   f   1975
# 2    c_1699   f   1984
# 3    c_5961   f   1962
# 4    c_5320   m   1943

# %%
customers.nunique()
# Out:
# client_id    8623
# sex             2
# birth          76
# dtype: int64

# %%
# tous les clients sont uniques,
customers.shape
# Out:
# (8623, 3)

# %%
customers['age'] = 2023 - customers['birth'] # avec la date du systeme library date time pour get

# %%
customers .head()
# Out:
#   client_id sex  birth  age
# 0    c_4410   f   1967   56
# 1    c_7839   f   1975   48
# 2    c_1699   f   1984   39
# 3    c_5961   f   1962   61
# 4    c_5320   m   1943   80

# %%
customers.isnull().sum()
# Out:
# client_id    0
# sex          0
# birth        0
# age          0
# dtype: int64

# %%
customers.describe()
# Out:
#              birth          age
# count  8623.000000  8623.000000
# mean   1978.280877    44.719123
# std      16.919535    16.919535
# min    1929.000000    19.000000
# 25%    1966.000000    31.000000
# 50%    1979.000000    44.000000
# 75%    1992.000000    57.000000
# max    2004.000000    94.000000

# %%
customers.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f48e41bb910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f48df93cdf0>]],
#       dtype=object)

# %%
customers[customers['age'] > 90]
# Out:
#      client_id sex  birth  age
# 418     c_5302   m   1929   94
# 701     c_2144   f   1932   91
# 751     c_4812   m   1931   92
# 1086    c_3218   f   1930   93
# 1588    c_1455   f   1932   91
# 2491    c_8362   f   1929   94
# 2738    c_6154   f   1932   91
# 3112    c_4334   m   1931   92
# 3272    c_2438   f   1932   91
# 3994    c_4679   f   1930   93
# 4569     c_577   m   1929   94
# 4574    c_8350   f   1931   92
# 5138    c_7232   f   1930   93
# 5627    c_8093   m   1932   91
# 5988     c_418   f   1931   92
# 6470    c_6758   f   1932   91
# 7550     c_353   m   1930   93

# %% [markdown]
# ### Products

# %%
products = pd.read_csv('products.csv', sep=',')

# %%
products.shape
# Out:
# (3287, 3)

# %%
products.head()
# Out:
#   id_prod  price  categ
# 0  0_1421  19.99      0
# 1  0_1368   5.13      0
# 2   0_731  17.99      0
# 3   1_587   4.99      1
# 4  0_1507   3.99      0

# %%
products.nunique()
# Out:
# id_prod    3287
# price      1455
# categ         3
# dtype: int64

# %%
products.isnull().sum()
# Out:
# id_prod    0
# price      0
# categ      0
# dtype: int64

# %%
#Il y a trois catégories de productuits
products.categ.unique()
# Out:
# array([0, 1, 2])

# %%
products.describe()
# Out:
#              price        categ
# count  3287.000000  3287.000000
# mean     21.856641     0.370246
# std      29.847908     0.615387
# min      -1.000000     0.000000
# 25%       6.990000     0.000000
# 50%      13.060000     0.000000
# 75%      22.990000     1.000000
# max     300.000000     2.000000

# %%
products[products['price'] ==-1]
# Out:
#     id_prod  price  categ
# 731     T_0   -1.0      0

# %%
products.price.hist()

# %%
#Eliminer les données test
products.drop(products.loc[products['id_prod'] == 'T_0'].index, inplace=True)

# %%
products.shape
# Out:
# (3286, 3)

# %%
products[products['price'] ==-1]
# Out:
# Empty DataFrame
# Columns: [id_prod, price, categ]
# Index: []

# %% [markdown]
# ### Transaction

# %%
transaction= pd.read_csv('transactions.csv', sep=',')

# %%
transaction.shape
# Out:
# (679532, 4)

# %%
transaction .describe()
# Out:
#        id_prod                             date session_id client_id
# count   679532                           679532     679532    679532
# unique    3267                           679371     342316      8602
# top      1_369  test_2021-03-01 02:30:02.237413        s_0    c_1609
# freq      2252                               13        200     25488

# %%
transaction.tail()
# Out:
#        id_prod                        date session_id client_id
# 679527  0_1551  2022-01-15 13:05:06.246925   s_150195    c_8489
# 679528   1_639  2022-03-19 16:03:23.429229   s_181434    c_4370
# 679529  0_1425  2022-12-20 04:33:37.584749   s_314704     c_304
# 679530  0_1994  2021-07-16 20:36:35.350579    s_63204    c_2227
# 679531   1_523  2022-09-28 01:12:01.973763   s_274568    c_3873

# %%
transaction[transaction['session_id']== 's_325227']
# Out:
#        id_prod                        date session_id client_id
# 4       0_1509  2023-01-11 08:22:08.194479   s_325227    c_4232
# 187463  0_1412  2023-01-11 08:51:55.515020   s_325227    c_4232
# 404411  0_1380  2023-01-11 08:25:51.777869   s_325227    c_4232
# 530937   1_653  2023-01-11 08:11:12.250882   s_325227    c_4232

# %%
#shape: (679532, 4)
transaction.nunique()
# Out:
# id_prod         3267
# date          679371
# session_id    342316
# client_id       8602
# dtype: int64

# %%
transaction.isnull().sum()
# Out:
# id_prod       0
# date          0
# session_id    0
# client_id     0
# dtype: int64

# %%
# je vais voir le type de donnée pour date pour après la convertir
transaction.dtypes
# Out:
# id_prod       object
# date          object
# session_id    object
# client_id     object
# dtype: object

# %%
#split colonne date
transaction[['date_s', 'time']] = transaction['date'].str.split(expand=True)

# %%
transaction.head(3)
# Out:
#   id_prod                        date session_id client_id      date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103  2022-05-20
# 1   1_251  2022-02-02 07:55:19.149409   s_158752    c_8534  2022-02-02
# 2  0_1277  2022-06-18 15:44:33.155329   s_225667    c_6714  2022-06-18
#
#               time
# 0  13:21:29.043970
# 1  07:55:19.149409
# 2  15:44:33.155329

# %%
#Eliminer données de test
data_test =transaction[transaction['date_s'] == 'test_2021-03-01']
data_test.columns
data_test.client_id.unique()

data_test.id_prod.unique()
#Eliminer les données test
transaction.drop(transaction.loc[transaction['date_s'] == 'test_2021-03-01'].index,
                 inplace=True)

print("Shape après avoir éliminé les données de test",transaction.shape)
# Out:
# Shape après avoir éliminé les données de test (679332, 6)

# %%
#Convertir la colonne au format date
transaction['date_s'] = pd.to_datetime(transaction['date_s'])

# %%
transaction.head()
# Out:
#   id_prod                        date session_id client_id     date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103 2022-05-20
# 1   1_251  2022-02-02 07:55:19.149409   s_158752    c_8534 2022-02-02
# 2  0_1277  2022-06-18 15:44:33.155329   s_225667    c_6714 2022-06-18
# 3   2_209  2021-06-24 04:19:29.835891    s_52962    c_6941 2021-06-24
# 4  0_1509  2023-01-11 08:22:08.194479   s_325227    c_4232 2023-01-11
#
#               time
# 0  13:21:29.043970
# 1  07:55:19.149409
# 2  15:44:33.155329
# 3  04:19:29.835891
# 4  08:22:08.194479

# %%
# Je récupere le mois et l'année pour après calculer l'évoultion de CA
transaction['month'] = transaction['date_s'].dt.month

# %%
transaction['year'] = transaction['date_s'].dt.year

# %%
transaction.head()
# Out:
#   id_prod                        date session_id client_id     date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103 2022-05-20
# 1   1_251  2022-02-02 07:55:19.149409   s_158752    c_8534 2022-02-02
# 2  0_1277  2022-06-18 15:44:33.155329   s_225667    c_6714 2022-06-18
# 3   2_209  2021-06-24 04:19:29.835891    s_52962    c_6941 2021-06-24
# 4  0_1509  2023-01-11 08:22:08.194479   s_325227    c_4232 2023-01-11
#
#               time  month  year
# 0  13:21:29.043970      5  2022
# 1  07:55:19.149409      2  2022
# 2  15:44:33.155329      6  2022
# 3  04:19:29.835891      6  2021
# 4  08:22:08.194479      1  2023

# %% [markdown]
# ## Jointures

# %% [markdown]
# ### Jointure products et transaction

# %%
prod_trans= pd.merge(transaction, products, on ='id_prod', how='outer', indicator=True)
# join lefth ? pour ne pas prendre les produits  pas vendues

# %%
prod_trans.shape
# Out:
# (679353, 11)

# %%
prod_trans.head()
# Out:
#   id_prod                        date session_id client_id     date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103 2022-05-20
# 1  0_1518  2021-09-26 12:37:29.780414    s_95811    c_6197 2021-09-26
# 2  0_1518  2021-05-06 17:14:43.117440    s_30782     c_682 2021-05-06
# 3  0_1518  2022-03-16 18:57:10.420103   s_180057    c_5932 2022-03-16
# 4  0_1518  2022-11-12 18:58:10.574853   s_296584    c_7217 2022-11-12
#
#               time  month    year  price  categ _merge
# 0  13:21:29.043970    5.0  2022.0   4.18    0.0   both
# 1  12:37:29.780414    9.0  2021.0   4.18    0.0   both
# 2  17:14:43.117440    5.0  2021.0   4.18    0.0   both
# 3  18:57:10.420103    3.0  2022.0   4.18    0.0   both
# 4  18:58:10.574853   11.0  2022.0   4.18    0.0   both

# %%
prod_trans._merge.unique()
# Out:
# [both, left_only, right_only]
# Categories (3, object): [both, left_only, right_only]

# %%
# Les produits vendues ne sont pas dans la data frame products, on ne connait pas le prix.
#Le CA peut être affecté par cette manque d'information.

# Faire l'imputation de valeurs avec la moyenne, categorie 0.#
#outer, on peux savoir 
prod_trans[prod_trans['_merge'] == 'left_only']
#shape: (221, 11)
# Out:
#        id_prod                        date session_id client_id     date_s  \
# 542560  0_2245  2022-09-23 07:22:38.636773   s_272266    c_4746 2022-09-23
# 542765  15:55:49.728644    3.0  2021.0    NaN    NaN  left_only
# 542766  09:23:31.000720   11.0  2022.0    NaN    NaN  left_only
# 542767  04:57:20.090378    7.0  2022.0    NaN    NaN  left_only
# 542768  03:28:02.080884    3.0  2022.0    NaN    NaN  left_only
# 542769  14:14:40.444177   12.0  2021.0    NaN    NaN  left_only
# 542770  13:36:19.612226   10.0  2021.0    NaN    NaN  left_only
# 542771  04:31:18.063440    5.0  2022.0    NaN    NaN  left_only
# 542772  19:58:42.716401   10.0  2022.0    NaN    NaN  left_only
# 542773  17:35:59.911427    8.0  2022.0    NaN    NaN  left_only
# 542774  01:51:40.749182    8.0  2021.0    NaN    NaN  left_only
# 542775  23:29:02.347672    3.0  2021.0    NaN    NaN  left_only
# 542776  09:06:03.504061    8.0  2021.0    NaN    NaN  left_only
# 542777  19:59:19.462288    3.0  2022.0    NaN    NaN  left_only
# 542778  11:35:20.319501    5.0  2022.0    NaN    NaN  left_only
# 542779  09:05:43.952857    2.0  2022.0    NaN    NaN  left_only
# 542780  22:34:54.589921   12.0  2021.0    NaN    NaN  left_only

# %%
 idx_prod_sans_price = prod_trans[prod_trans['_merge'] == 'left_only'].index

# %% [markdown]
# #### Imputation para la moyenne de produits vendues sans le price

# %%
# Je calcule la moyenne du prix du produits de la categorie 0,
# car tous les id_prod comencent par 0
mean_price = round(prod_trans[prod_trans['categ'] == 0].price.mean(),2)
mean_price
# Out:
# 10.64

# %%
# Le total de tous le valeurs nan du merge (left_only), c'est egale à la shape
prod_trans.price.isna().sum()
# Out:
# 221

# %%
#Imputation avec la moyenne
prod_trans.price.fillna(mean_price, inplace=True)

# %%
#Remplir avec 0 dans la colonne categ 
prod_trans.categ.fillna(0, inplace = True)

# %%
#je verifie que l'imputation est faite
prod_trans[prod_trans['_merge'] == 'left_only'].head()
# Out:
#        id_prod                        date session_id client_id     date_s  \
# 542560  0_2245  2022-09-23 07:22:38.636773   s_272266    c_4746 2022-09-23
# 542561  0_2245  2022-07-23 09:24:14.133889   s_242482    c_6713 2022-07-23
# 542562  0_2245  2022-12-03 03:26:35.696673   s_306338    c_5108 2022-12-03
# 542563  0_2245  2021-08-16 11:33:25.481411    s_76493    c_1391 2021-08-16
# 542564  0_2245  2022-07-16 05:53:01.627491   s_239078    c_7954 2022-07-16
#
#                    time  month    year  price  categ     _merge
# 542560  07:22:38.636773    9.0  2022.0  10.64    0.0  left_only
# 542561  09:24:14.133889    7.0  2022.0  10.64    0.0  left_only
# 542562  03:26:35.696673   12.0  2022.0  10.64    0.0  left_only
# 542563  11:33:25.481411    8.0  2021.0  10.64    0.0  left_only
# 542564  05:53:01.627491    7.0  2022.0  10.64    0.0  left_only

# %%
# produits non vendus,
#je peux l'elever dans la transaction
prod_trans[prod_trans['_merge'] == 'right_only']
# Out:
#        id_prod date session_id client_id date_s time  month  year   price  \
# 679332  0_1016  NaN        NaN       NaN    NaT  NaN    NaN   NaN   35.06
# 679333  0_1780  NaN        NaN       NaN    NaT  NaN    NaN   NaN    1.67
# 679334  0_1062  NaN        NaN       NaN    NaT  NaN    NaN   NaN   20.08
# 679335  0_1119  NaN        NaN       NaN    NaT  NaN    NaN   NaN    2.99
# 679336  0_1014  NaN        NaN       NaN    NaT  NaN    NaN   NaN    1.15
# 679337     1_0  NaN        NaN       NaN    NaT  NaN    NaN   NaN   31.82
# 679338  0_1318  NaN        NaN       NaN    NaT  NaN    NaN   NaN   20.92
# 679339  0_1800  NaN        NaN       NaN    NaT  NaN    NaN   NaN   22.05
# 679340  0_1645  NaN        NaN       NaN    NaT  NaN    NaN   NaN    2.99
# 679341   0_322  NaN        NaN       NaN    NaT  NaN    NaN   NaN    2.99
# 679342  0_1620  NaN        NaN       NaN    NaT  NaN    NaN   NaN    0.80
# 679343  0_1025  NaN        NaN       NaN    NaT  NaN    NaN   NaN   24.99
# 679344    2_87  NaN        NaN       NaN    NaT  NaN    NaN   NaN  220.99
# 679345   1_394  NaN        NaN       NaN    NaT  NaN    NaN   NaN   39.73
# 679346    2_72  NaN        NaN       NaN    NaT  NaN    NaN   NaN  141.32
# 679347   0_310  NaN        NaN       NaN    NaT  NaN    NaN   NaN    1.94
# 679348  0_1624  NaN        NaN       NaN    NaT  NaN    NaN   NaN   24.50
# 679349    2_86  NaN        NaN       NaN    NaT  NaN    NaN   NaN  132.36
# 679350   0_299  NaN        NaN       NaN    NaT  NaN    NaN   NaN   22.99
# 679351   0_510  NaN        NaN       NaN    NaT  NaN    NaN   NaN   23.66
# 679352  0_2308  NaN        NaN       NaN    NaT  NaN    NaN   NaN   20.28
#
#         categ      _merge
# 679332    0.0  right_only
# 679333    0.0  right_only
# 679334    0.0  right_only
# 679335    0.0  right_only
# 679336    0.0  right_only
# 679337    1.0  right_only
# 679338    0.0  right_only
# 679339    0.0  right_only
# 679340    0.0  right_only
# 679341    0.0  right_only
# 679342    0.0  right_only
# 679343    0.0  right_only
# 679344    2.0  right_only
# 679345    1.0  right_only
# 679346    2.0  right_only
# 679347    0.0  right_only
# 679348    0.0  right_only
# 679349    2.0  right_only
# 679350    0.0  right_only
# 679351    0.0  right_only
# 679352    0.0  right_only

# %%
#Eliminer les produits non vendus
prod_trans.drop(prod_trans[prod_trans['_merge'] == 'right_only'].index, inplace=True)

# %%
# Vérification s'ils sont éliminés
prod_trans[prod_trans['_merge'] == 'right_only']
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id, date_s, time, month, year, price, categ, _merge]
# Index: []

# %%
# J'élimine la colonne _merge, sinon ça ne permet pas de faire une 2em jointure
prod_trans.drop(['_merge'], axis=1, inplace=True)

# %% [markdown]
# ### Jointure products, transaction and customers

# %%
ventes = pd.merge(prod_trans, customers, on ='client_id', how='outer', indicator= True)

# %%
ventes.shape
# Out:
# (679355, 14)

# %%
ventes.head()
# Out:
#   id_prod                        date session_id client_id     date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103 2022-05-20
# 1  0_1518  2021-07-20 13:21:29.043970    s_64849     c_103 2021-07-20
# 2  0_1518  2022-08-20 13:21:29.043970   s_255965     c_103 2022-08-20
# 3  0_1418  2022-06-18 01:49:37.823274   s_225411     c_103 2022-06-18
# 4  0_1418  2021-08-18 01:49:37.823274    s_77214     c_103 2021-08-18
#
#               time  month    year  price  categ sex  birth  age _merge
# 0  13:21:29.043970    5.0  2022.0   4.18    0.0   f   1986   37   both
# 1  13:21:29.043970    7.0  2021.0   4.18    0.0   f   1986   37   both
# 2  13:21:29.043970    8.0  2022.0   4.18    0.0   f   1986   37   both
# 3  01:49:37.823274    6.0  2022.0   8.57    0.0   f   1986   37   both
# 4  01:49:37.823274    8.0  2021.0   8.57    0.0   f   1986   37   both

# %%
#Clients qui n'ont pas fait d'achats
ventes[ventes['_merge'] == 'right_only']
# Out:
#        id_prod date session_id client_id date_s time  month  year  price  \
# 679332     NaN  NaN        NaN    c_8253    NaT  NaN    NaN   NaN    NaN
# 679333     NaN  NaN        NaN    c_3789    NaT  NaN    NaN   NaN    NaN
# 679334     NaN  NaN        NaN    c_4406    NaT  NaN    NaN   NaN    NaN
# 679335     NaN  NaN        NaN      ct_0    NaT  NaN    NaN   NaN    NaN
# 679336     NaN  NaN        NaN    c_2706    NaT  NaN    NaN   NaN    NaN
# 679337     NaN  NaN        NaN    c_3443    NaT  NaN    NaN   NaN    NaN
# 679338     NaN  NaN        NaN    c_4447    NaT  NaN    NaN   NaN    NaN
# 679339     NaN  NaN        NaN    c_3017    NaT  NaN    NaN   NaN    NaN
# 679340     NaN  NaN        NaN    c_4086    NaT  NaN    NaN   NaN    NaN
# 679341     NaN  NaN        NaN    c_6930    NaT  NaN    NaN   NaN    NaN
# 679342     NaN  NaN        NaN    c_4358    NaT  NaN    NaN   NaN    NaN
# 679343     NaN  NaN        NaN    c_8381    NaT  NaN    NaN   NaN    NaN
# 679344     NaN  NaN        NaN    c_1223    NaT  NaN    NaN   NaN    NaN
# 679345     NaN  NaN        NaN    c_6862    NaT  NaN    NaN   NaN    NaN
# 679346     NaN  NaN        NaN    c_5245    NaT  NaN    NaN   NaN    NaN
# 679347     NaN  NaN        NaN    c_5223    NaT  NaN    NaN   NaN    NaN
# 679348     NaN  NaN        NaN    c_6735    NaT  NaN    NaN   NaN    NaN
# 679349     NaN  NaN        NaN     c_862    NaT  NaN    NaN   NaN    NaN
# 679350     NaN  NaN        NaN    c_7584    NaT  NaN    NaN   NaN    NaN
# 679351     NaN  NaN        NaN      c_90    NaT  NaN    NaN   NaN    NaN
# 679352     NaN  NaN        NaN     c_587    NaT  NaN    NaN   NaN    NaN
# 679353     NaN  NaN        NaN      ct_1    NaT  NaN    NaN   NaN    NaN
# 679354     NaN  NaN        NaN    c_3526    NaT  NaN    NaN   NaN    NaN
#
#         categ sex  birth  age      _merge
# 679332    NaN   f   2001   22  right_only
# 679333    NaN   f   1997   26  right_only
# 679334    NaN   f   1998   25  right_only
# 679335    NaN   f   2001   22  right_only
# 679336    NaN   f   1967   56  right_only
# 679337    NaN   m   1959   64  right_only
# 679338    NaN   m   1956   67  right_only
# 679339    NaN   f   1992   31  right_only
# 679340    NaN   f   1992   31  right_only
# 679341    NaN   m   2004   19  right_only
# 679342    NaN   m   1999   24  right_only
# 679343    NaN   f   1965   58  right_only
# 679344    NaN   m   1963   60  right_only
# 679345    NaN   f   2002   21  right_only
# 679346    NaN   f   2004   19  right_only
# 679347    NaN   m   2003   20  right_only
# 679348    NaN   m   2004   19  right_only
# 679349    NaN   f   1956   67  right_only
# 679350    NaN   f   1960   63  right_only
# 679351    NaN   m   2001   22  right_only
# 679352    NaN   m   1993   30  right_only
# 679353    NaN   m   2001   22  right_only
# 679354    NaN   m   1956   67  right_only

# %%
ventes[ventes['_merge'] == 'left_only']
#shape:(21, 14) les produit pas vendues
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id, date_s, time, month, year, price, categ, sex, birth, age, _merge]
# Index: []

# %% [markdown]
# ## Graphiques évolution du CA dans le temps

# %%
sums = ventes.groupby(['categ', 'month'])['price'].sum().reset_index(level=0)
plt.title('CA en 2021')

plt.plot(sums[sums['categ'] == 1]['price'], label='cat 0')

# %%
sums = ventes.groupby(['categ', 'month'])['price'].sum().reset_index(level=0)
plt.title('CA en 2021')

plt.plot(sums[sums['categ'] == 2]['price'], label='cat 0')

# %%
def plot_ca (year,ventes):
    sums = ventes[ventes['year'] == year].groupby(['categ', 'month'])['price'].sum().reset_index(level=0)
    plt.title('CA en {}'.format(year))
   #plt.legend()   
    for c in sums['categ'].unique():        
        sums[sums['categ'] == c]['price'].plot(figsize=(15,7));

# %% [markdown]
# ### Graphique CA par an et par catégorie

# %%
# le mois d'octobre enlever du 2021 pour faire analyse bivari
# il y a pas de données dans lle mois d'oct
plot_ca(2021, ventes)
# blue cat 0
# orange cat 1
# vert cat 2

# %%
plot_ca(2022,ventes)

# %%
plot_ca(2023,ventes)

# %% [markdown]
# ### Enlever le mois d'octobre pour l'année 2021

# %%
# dfa.drop(dfa.loc[dfa['date']==2021-10].index,inplace=True)

# %%
ventes.head()
# Out:
#   id_prod                        date session_id client_id     date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103 2022-05-20
# 1  0_1518  2021-07-20 13:21:29.043970    s_64849     c_103 2021-07-20
# 2  0_1518  2022-08-20 13:21:29.043970   s_255965     c_103 2022-08-20
# 3  0_1418  2022-06-18 01:49:37.823274   s_225411     c_103 2022-06-18
# 4  0_1418  2021-08-18 01:49:37.823274    s_77214     c_103 2021-08-18
#
#               time  month    year  price  categ sex  birth  age _merge
# 0  13:21:29.043970    5.0  2022.0   4.18    0.0   f   1986   37   both
# 1  13:21:29.043970    7.0  2021.0   4.18    0.0   f   1986   37   both
# 2  13:21:29.043970    8.0  2022.0   4.18    0.0   f   1986   37   both
# 3  01:49:37.823274    6.0  2022.0   8.57    0.0   f   1986   37   both
# 4  01:49:37.823274    8.0  2021.0   8.57    0.0   f   1986   37   both

# %%
#ventes.drop(ventes.loc[ventes['date_s']==2021-10].index,inplace=True)

# %%
# Ventes avec 10/2021 (679355, 14)
ventes.shape
# Out:
# (679355, 14)

# %% [markdown]
# Eliminer le mois d'Octobre en 2021

# %%
ventes.drop(ventes.loc[(ventes['year'] == 2021) & (ventes['month'] == 10)].index, inplace=True)

# %%
ventes.shape
# Out:
# (657749, 14)

# %%
679355 - 657749
# Out:
# 21606

# %%
ventes[(ventes['year'] == 2021) & (ventes['month'] == 10)]
# Out:
# Empty DataFrame
# Columns: [id_prod, date, session_id, client_id, date_s, time, month, year, price, categ, sex, birth, age, _merge]
# Index: []

# %%
plot_ca(2021,ventes)

# %%
ventes.head()
# Out:
#   id_prod                        date session_id client_id     date_s  \
# 0  0_1518  2022-05-20 13:21:29.043970   s_211425     c_103 2022-05-20
# 1  0_1518  2021-07-20 13:21:29.043970    s_64849     c_103 2021-07-20
# 2  0_1518  2022-08-20 13:21:29.043970   s_255965     c_103 2022-08-20
# 3  0_1418  2022-06-18 01:49:37.823274   s_225411     c_103 2022-06-18
# 4  0_1418  2021-08-18 01:49:37.823274    s_77214     c_103 2021-08-18
#
#               time  month    year  price  categ sex  birth  age _merge
# 0  13:21:29.043970    5.0  2022.0   4.18    0.0   f   1986   37   both
# 1  13:21:29.043970    7.0  2021.0   4.18    0.0   f   1986   37   both
# 2  13:21:29.043970    8.0  2022.0   4.18    0.0   f   1986   37   both
# 3  01:49:37.823274    6.0  2022.0   8.57    0.0   f   1986   37   both
# 4  01:49:37.823274    8.0  2021.0   8.57    0.0   f   1986   37   both

# %%
#ventes[(ventes['year'] == 2021) & (ventes['month'] == 10) & (ventes['categ'] == 2)]

# 18.762 rows  pour la categ 0
#  1.666 rows pour  la categ 1
#  1.171 rows  pour la categ 2

#Les données pour les categ 1 et 2 sont tres peu nombreux

# %%
#ventes['year']= ventes.year.astype(int)

# %%
#ventes['month'] = ventes.month.astype(int)

# %%
#Eliminer le mois d'Octobre en 2021
#ventes.drop(ventes[(ventes['year'] == 2021) & (ventes['month'] == 10)].index, inplace=True)

# %%
#ventes= ventes.set_index('date_s')

# %%
#data_new = ventes[~ ventes.index.month.isin([10])]

# %%
plot_ca(2021,ventes)

# %% [markdown]
# ### Décomposition en moyenne mobile pour évaluer la tendance globale

# %%
ventes.isnull().sum()
# Out:
# id_prod       23
# date          23
# session_id    23
# client_id      0
# date_s        23
# time          23
# month         23
# year          23
# price         23
# categ         23
# sex            0
# birth          0
# age            0
# _merge         0
# dtype: int64

# %%
ventes.describe()
# Out:
#                month           year          price          categ  \
# count  657726.000000  657726.000000  657726.000000  657726.000000
# mean        6.389524    2021.692528      17.538013       0.450229
# std         3.478330       0.615343      18.337931       0.595734
# min         1.000000    2021.000000       0.620000       0.000000
# 25%         3.000000    2021.000000       8.990000       0.000000
# 50%         6.000000    2022.000000      13.990000       0.000000
# 75%         9.000000    2022.000000      19.080000       1.000000
# max        12.000000    2023.000000     300.000000       2.000000
#
#                birth            age
# count  657749.000000  657749.000000
# mean     1977.776853      45.223147
# std        13.614875      13.614875
# min      1929.000000      19.000000
# 25%      1970.000000      36.000000
# 50%      1980.000000      43.000000
# 75%      1987.000000      53.000000
# max      2004.000000      94.000000

# %%
ventes.shape
# Out:
# (657749, 14)

# %%
ca_month = ventes[['date_s', 'price']].copy()

# %%
ca_month
# Out:
#            date_s  price
# 0      2022-05-20   4.18
# 1      2021-07-20   4.18
# 2      2022-08-20   4.18
# 3      2022-06-18   8.57
# 4      2021-08-18   8.57
# ...           ...    ...
# 679350        NaT    NaN
# 679351        NaT    NaN
# 679352        NaT    NaN
# 679353        NaT    NaN
# 679354        NaT    NaN
#
# [657749 rows x 2 columns]

# %%
ca_month.dtypes
# Out:
# date_s    datetime64[ns]
# price            float64
# dtype: object

# %%
start_date = "2021-10-01"

end_date = "2021-10-31"


after_start_date = ca_month["date_s"] >= start_date

before_end_date = ca_month["date_s"] <= end_date

between_two_dates = after_start_date & before_end_date

ca_month.loc[between_two_dates]
# Out:
# Empty DataFrame
# Columns: [date_s, price]
# Index: []

# %%
ca_month.set_index('date_s', inplace=True)

# %%
ca_month = ca_month.groupby(pd.Grouper(freq="W"))['price'].sum().reset_index(level=0)
# reset_index(level=0) -- pone date_s como col, sino lo deja como indice

# %%
ca_month[ '4week_rolling_avg' ] = ca_month.price.rolling(4).mean()

# %%
ca_month.head()
# Out:
#       date_s      price  4week_rolling_avg
# 0 2021-03-07  110495.20                NaN
# 1 2021-03-14  105693.24                NaN
# 2 2021-03-21  112059.08                NaN
# 3 2021-03-28  109472.99        109430.1275
# 4 2021-04-04  107948.86        108793.5425

# %%
plt.figure( figsize = ( 12, 5)) 

sns.lineplot( x = 'date_s', 
             y = 'price', 
             data = ca_month, 
             label = 'CA')

sns.lineplot( x = 'date_s', 
             y = '4week_rolling_avg', 
             data = ca_month, 
             label = 'Rollingavg')

plt.xlabel('Mois du 2021 au 2023')
plt.ylabel('CA') 
plt.show()

# %% [markdown]
# ## Test 2

# %%
ventes2 =ventes[['id_prod', 'date_s', 'session_id', 'client_id', 'month','year', 'price', 'categ', 'sex', 'birth', 'age']]

# %%
ventes2.head()
# Out:
#   id_prod     date_s session_id client_id  month    year  price  categ sex  \
# 0  0_1518 2022-05-20   s_211425     c_103    5.0  2022.0   4.18    0.0   f
# 1  0_1518 2021-07-20    s_64849     c_103    7.0  2021.0   4.18    0.0   f
# 2  0_1518 2022-08-20   s_255965     c_103    8.0  2022.0   4.18    0.0   f
# 3  0_1418 2022-06-18   s_225411     c_103    6.0  2022.0   8.57    0.0   f
# 4  0_1418 2021-08-18    s_77214     c_103    8.0  2021.0   8.57    0.0   f
#
#    birth  age
# 0   1986   37
# 1   1986   37
# 2   1986   37
# 3   1986   37
# 4   1986   37

# %%
ventes2.dtypes
# Out:
# id_prod               object
# date_s        datetime64[ns]
# session_id            object
# client_id             object
# month                float64
# year                 float64
# price                float64
# categ                float64
# sex                   object
# birth                  int64
# age                    int64
# dtype: object

# %%
ventes2.columns = ['id_prod', 'date', 'session_id', 'client_id', 'month','year', 'price', 'categ', 'sex', 'birth', 'age']

# %%
ventes2.shape
# Out:
# (657749, 11)

# %%
ventes2['date'] = ventes2['date'].dt.to_period('M')
#ventes.drop(ventes.loc[ventes['date_s']==2021-10].index,inplace=True)
# Out:
# <ipython-input-101-0ee5e4518ec8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ventes2['date'] = ventes2['date'].dt.to_period('M')

# %%
ventes2.head()
# Out:
#   id_prod     date session_id client_id  month    year  price  categ sex  \
# 0  0_1518  2022-05   s_211425     c_103    5.0  2022.0   4.18    0.0   f
# 1  0_1518  2021-07    s_64849     c_103    7.0  2021.0   4.18    0.0   f
# 2  0_1518  2022-08   s_255965     c_103    8.0  2022.0   4.18    0.0   f
# 3  0_1418  2022-06   s_225411     c_103    6.0  2022.0   8.57    0.0   f
# 4  0_1418  2021-08    s_77214     c_103    8.0  2021.0   8.57    0.0   f
#
#    birth  age
# 0   1986   37
# 1   1986   37
# 2   1986   37
# 3   1986   37
# 4   1986   37

# %%
ventes2.drop(ventes2.loc[ventes2['date']==2021-10].index,inplace=True)
# Out:
# /home/ac/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
ventes2.shape
# Out:
# (657749, 11)

# %%
ca_month2 = ventes2[['date', 'price']].copy()

# %%
ca_month2.set_index('date', inplace=True)

# %%
ca_month2.head()
# Out:
#          price
# date
# 2022-05   4.18
# 2021-07   4.18
# 2022-08   4.18
# 2022-06   8.57
# 2021-08   8.57

# %% [markdown]
# Le group_by je dois le faire par mois, car j'ai perdu la semaine

# %%
ca_month2= ca_month2.groupby(pd.Grouper(freq="M"))['price'].sum().reset_index(level=0)

# %%
ca_month2.head()
# Out:
#       date      price
# 0  2021-03  482536.37
# 1  2021-04  476258.26
# 2  2021-05  493028.59
# 3  2021-06  484163.04
# 4  2021-07  482877.96

# %%
ca_month2[ '4week_rolling_avg' ] = ca_month2.price.rolling(4).mean()

# %%
ca_month2
# Out:
#        date      price  4week_rolling_avg
# 0   2021-03  482536.37                NaN
# 1   2021-04  476258.26                NaN
# 2   2021-05  493028.59                NaN
# 3   2021-06  484163.04        483996.5650
# 4   2021-07  482877.96        484081.9625
# 5   2021-08  482380.55        485612.5350
# 6   2021-09  507368.36        489197.4775
# 7   2021-10       0.00        368156.7175
# 8   2021-11  516274.13        376505.7600
# 9   2021-12  525991.76        387408.5625
# 10  2022-01  525392.19        391914.5200
# 11  2022-02  535688.54        525836.6550
# 12  2022-03  515573.57        525661.5150
# 13  2022-04  493147.90        517450.5500
# 14  2022-05  517302.84        515428.2125
# 15  2022-06  496090.60        505528.7275
# 16  2022-07  510910.80        504363.0350
# 17  2022-08  506552.39        507714.1575
# 18  2022-09  494210.29        501941.0200
# 19  2022-10  508024.17        504924.4125
# 20  2022-11  496781.98        501392.2075
# 21  2022-12  510283.34        502324.9450
# 22  2023-01  517615.03        508176.1300
# 23  2023-02  456754.24        495358.6475

# %%
ca_month2['date'] = ca_month2['date'].astype(str)
ca_month2['date'] = pd.to_datetime(ca_month2['date'])
ca_month2.dtypes
# Out:
# date                 datetime64[ns]
# price                       float64
# 4week_rolling_avg           float64
# dtype: object

# %%
plt.figure( figsize = ( 12, 5)) 

sns.lineplot( x = 'date', 
             y = 'price', 
             data = ca_month2, 
             label = 'CA')

sns.lineplot( x = 'date', 
             y = '4week_rolling_avg', 
             data = ca_month2, 
             label = 'Rollingavg')

plt.xlabel('2021 au 2023 ventes2')
plt.ylabel('CA') 
plt.show()

# %% [markdown]
# ## Les tops et les flops, la répartition par catégorie.

# %%
def tops_flops_prod(df,categ):
    data = df[df['categ'] == categ]
    ca = data.groupby(['id_prod'])['price'].sum().reset_index(level=0)
    tops = ca.sort_values('price', ascending=False).head(10)
    flops = ca.sort_values('price').head(10)
    
    return tops,flops

# %%
top_0,flop_0 = tops_flops_prod(ventes, 0)
top_1,flop_1 = tops_flops_prod(ventes, 1)
top_2,flop_2 = tops_flops_prod(ventes, 2)

# %%
print("Top 10 de produits categorie 0")
top_0
# Out:
# Top 10 de produits categorie 0
#     id_prod     price
# 486  0_1441  22389.21
# 464  0_1421  21809.09
# 456  0_1414  21395.52
# 497  0_1451  20789.60
# 459  0_1417  20364.68
# 493  0_1448  19754.42
# 474  0_1430  19253.43
# 518  0_1470  19197.99
# 389  0_1353  18650.67
# 391  0_1355  18401.31

# %%
f, ax = plt.subplots(figsize=(12,5)) 
ax.set_title('Top 10 de produits - categorie 0')
ax = sns.barplot(x="id_prod", y="price", data=top_0, palette="Blues_d")

# %%
print("Flops de produits categorie 0")
flop_0
# Out:
# Flops de produits categorie 0
#      id_prod  price
# 594   0_1539   0.99
# 2178   0_898   1.27
# 313   0_1284   1.38
# 1896   0_643   1.98
# 718   0_1653   1.98
# 2078   0_807   1.99
# 1783   0_541   1.99
# 664   0_1601   1.99
# 801   0_1728   2.27
# 1543   0_324   2.36

# %%
print("Top 10 de produits categorie 1")
top_1
# Out:
# Top 10 de produits categorie 1
#     id_prod     price
# 327   1_395  53950.39
# 299   1_369  53665.63
# 349   1_414  51615.78
# 315   1_383  51080.38
# 441   1_498  49474.29
# 340   1_406  47908.11
# 296   1_366  46691.44
# 317   1_385  46496.11
# 368   1_431  46323.45
# 309   1_378  45875.64

# %%
print("Flops de produits categorie 1")
flop_1
# Out:
# Flops de produits categorie 1
#     id_prod  price
# 356   1_420  14.24
# 139   1_224  19.80
# 411   1_470  21.64
# 414   1_473  26.91
# 338   1_404  29.55
# 40    1_135  39.95
# 331   1_399  43.89
# 457   1_511  44.85
# 375   1_438  47.16
# 360   1_424  49.10

# %%
print("Top 10 de produits categorie 2")
top_2
# Out:
# Top 10 de produits categorie 2
#     id_prod     price
# 67    2_159  92265.68
# 41    2_135  67403.23
# 16    2_112  62840.10
# 5     2_102  58962.58
# 123   2_209  55362.09
# 14    2_110  51916.50
# 172    2_39  51147.18
# 75    2_166  51068.88
# 177    2_43  48363.09
# 116   2_202  44393.49

# %%
print("Flops de produits categorie 2")
flop_2
# Out:
# Flops de produits categorie 2
#     id_prod   price
# 218    2_81   86.99
# 146    2_23  115.99
# 234    2_98  149.74
# 229    2_93  157.98
# 10    2_107  203.94
# 37    2_131  255.98
# 27    2_122  280.00
# 213    2_77  291.98
# 159    2_27  295.96
# 202    2_66  301.44

# %%
ca_client = ventes.groupby(['client_id'])['price'].sum().reset_index(level=0)
tops = ca_client.sort_values('price', ascending=False).head(10)
flops = ca_client[ca_client['price'] > 0].sort_values('price').head(10)

# %%
tops
# Out:
#      client_id      price
# 678     c_1609  312755.08
# 4397    c_4958  282654.61
# 6349    c_6714  149847.59
# 2727    c_3454  111798.63
# 2110    c_2899    5214.05
# 635     c_1570    5136.14
# 2516    c_3263    5129.89
# 7021    c_7319    5120.55
# 7807    c_8026    4980.05
# 4737    c_5263    4964.87

# %%
flops
# Out:
#      client_id  price
# 7934    c_8140   8.30
# 7905    c_8114   9.98
# 1557     c_240  11.06
# 4053    c_4648  11.20
# 1993    c_2793  12.99
# 3864    c_4478  13.36
# 5513    c_5962  13.99
# 5601    c_6040  15.72
# 5465    c_5919  15.98
# 5365    c_5829  16.07

# %% [markdown]
# ## Courbe de Lorentz et gini

# %%
# CA par age 
ca_age = ventes.groupby(['age'])['price'].sum().reset_index(level=0)

# %%
ca = ca_age['price'].values
n = len(ca)
lorenz = np.cumsum(np.sort(ca)) / ca.sum()
lorenz = np.append([0],lorenz) # La courbe de Lorenz commence à 0

plt.axes().axis('equal')
xaxis = np.linspace(0-1/n, 1+1/n, n+1) #Il y a un segment de taille n pour chaque individu, plus 1 segment supplémentaire d'ordonnée 0. Le premier segment commence à 0-1/n, et le dernier termine à 1+1/n.
plt.plot(xaxis, lorenz, drawstyle='steps-post', color='green')
## line plot of equality
plt.plot([0,1], [0,1], color='k')
plt.title("Courbe de Lorentz")
plt.show()

# %%
AUC = (lorenz.sum() -lorenz[-1]/2 -lorenz[0]/2)/n # Surface sous la courbe de Lorenz. Le premier segment (lorenz[0]) est à moitié en dessous de 0, on le coupe donc en 2, on fait de même pour le dernier segment lorenz[-1] qui est à moitié au dessus de 1.
S = 0.5 - AUC # surface entre la première bissectrice et le courbe de Lorenz
gini = 2*S
print("Coefficient de Gini: ",gini)
# Out:
# Coefficient de Gini:  0.4463491271048772

# %% [markdown]
# ## Tests statistiques

# %% [markdown]
# ### Le lien entre le genre d’un client et les catégories des livres achetés

# %% [markdown]
# H0: Pas de rélation entre le sexe et catégorie

# %%
# Deux variables Qualitatives: Sexe - Catégorie
X = "sex"
Y = "categ"
#le tableau de contingence es calculé par pivot table 
cont = ventes[[X,Y]].pivot_table(index=X,columns=Y,aggfunc=len,margins=True,margins_name="Total")
cont
# Out:
# categ     0.0     1.0    2.0   Total
# sex
# f      197098  114087  16722  327907
# m      199813  111416  18590  329819
# Total  396911  225503  35312  657726

# %%
import seaborn as sns

tx = cont.loc[:,["Total"]]
ty = cont.loc[["Total"],:]
n = len(ventes)
indep = tx.dot(ty) / n

c = cont.fillna(0) # On remplace les valeurs nulles par 0
measure = (c-indep)**2/indep
xi_n = measure.sum().sum()
table = measure/xi_n
plt.figure(figsize=(10,6))
sns.heatmap(table.iloc[:-1,:-1],annot=c.iloc[:-1,:-1])

plt.show()

# %%
def test_pValue (p):
    print("P-val:", p)
    if p < 0.05:
        print("L'hypothèse nulle est rejeté")
    else:
        print("L'hypothèse nulle est accepté")

# %%
#P-val is considered 'significant' usually if this value is below 0.05, 
#which in this case it is. This indicates then an association between the two variables
#(one has an impact on the other).

chiVal, pVal, df, exp = chi2_contingency(cont)
print("chi-2:",chiVal)

test_pValue(pVal)
# Out:
# chi-2: 143.4684942757229
# P-val: 1.8567023620869968e-28
# L'hypothèse nulle est rejeté

# %% [markdown]
# Alors, il y a de rélation entre sexe et catégorie

# %% [markdown]
# ###  Le lien entre l’âge des clients et le montant total des achats: Deux variables quantitatives: Age - CA aporté

# %% [markdown]
# H0: Pas de relation entre l'âge et le chiffre d'affaire apporté

# %%
plt.hist(ca_age['price'], bins= 10)
plt.xlabel("Montant total des achats")
plt.show()

# %%
# Prix suit une lois normale?
kstest(ca_age['price'], 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# Since the p-value is less than .05, we reject the null hypothesis. We have sufficient evidence to say that the sample data does not come from a normal distribution.

# %%
#vars quanti/quanti
#le lien entre l’âge des clients et le montant total des achats

plt.scatter(ca_age['age'], ca_age['price'], alpha=0.5)
plt.xlabel("Age")
plt.ylabel("CA aporté")
plt.show()

# %%
#c_pers, p_val = st.pearsonr(ca_age['age'], ca_age['price'])
#print("Coeff pearson: ", round(c_pers,2))
#print("P-value: ", p_val)

#test_pValue(p_val)

# %%
# le prix ne suit pas une loi normale, alors on fait un test non paramétrique
# pour deux exemples --> Wilcoxon

stat, p = wilcoxon(ca_age['age'], ca_age['price'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
test_pValue(p)
# Out:
# Statistics=0.000, p=0.000
# P-val: 3.6060528034893936e-14
# L'hypothèse nulle est rejeté

# %% [markdown]
# Alors, il y a de rélation entre l'age et le chiffre d'affaire aporté

# %% [markdown]
# ### Lien entre âge des clients et la fréquence d’achat

# %% [markdown]
# H0: Pas de rélation entre l'âge et la fréquence d'achat

# %%
freq_achat = ventes[['id_prod','age']].groupby(['age']).count().reset_index(level=0)

# %%
freq_achat.head()
# Out:
#    age  id_prod
# 0   19    14769
# 1   20     4238
# 2   21     4468
# 3   22     4161
# 4   23     4299

# %%
# Fréquence d'achat suit une lois normale?
plt.hist(freq_achat['id_prod'], bins= 10)
plt.xlabel("Fréquence d'achat")
plt.show()

# %%
kstest(freq_achat['id_prod'], 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# Since the p-value is less than .05, we reject the null hypothesis. We have sufficient evidence to say that the sample data does not come from a normal distribution.

# %%
plt.scatter(freq_achat['age'], freq_achat['id_prod'], alpha=0.5)
plt.xlabel("Age")
plt.ylabel("Fréquence d'achat")
plt.show()

# %%
# Alors on fait test non paramétrique
# Faire testwilcoxon

stat, p = wilcoxon(freq_achat['age'], freq_achat['id_prod'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
test_pValue(p)
# Out:
# Statistics=0.000, p=0.000
# P-val: 3.6060528034893936e-14
# L'hypothèse nulle est rejeté

# %% [markdown]
# Alors, il y a de rélation entre l'age et la fréquence d'achat

# %% [markdown]
# ### Lien entre  l'âge des clients et la taille du panier moyen

# %%
session_panier = ventes.groupby(['age','session_id'])['price'].sum().reset_index()

# %%
session_panier.head(3)
# Out:
#    age session_id  price
# 0   19    s_10098  26.30
# 1   19    s_10128  13.11
# 2   19    s_10162  62.44

# %%
panier_moyen = session_panier.groupby(['age']).mean().reset_index()
panier_moyen.head(3)
# Out:
#    age      price
# 0   19  70.904475
# 1   20  69.577999
# 2   21  70.755485

# %%
# Requence d'achat suit une lois normale?
plt.hist(panier_moyen['price'], bins= 10)
plt.xlabel("Panier moyen")
plt.show()

# %%
kstest(panier_moyen['price'], 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
plt.scatter(panier_moyen['age'], panier_moyen['price'], alpha=0.5)
plt.xlabel("Age")
plt.ylabel("Panier moyen")
plt.show()

# %%
# Alors on fait test non paramétrique
# Faire testwilcoxon

stat, p = wilcoxon(panier_moyen['age'], panier_moyen['price'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
test_pValue(p)
# Out:
# Statistics=602.000, p=0.000
# P-val: 8.28434905658773e-06
# L'hypothèse nulle est rejeté

# %% [markdown]
# Alors, il y a de rélation entre age et la taille de panier

# %% [markdown]
# ### Lien entre âge et les catégories des livres achetés. Variable quantitative et une qualitative: Age - Catégorie

# %% [markdown]
# H0: Pas de rélation entre catégorie et age

# %%
X = "categ" # qualitative
Y = "age" # quantitative

# %%
# si pval < 0.05, normal distribution is not assumed
#else: normal distribution is assumed

kstest(ventes["age"], 'norm')
# Out:
# KstestResult(statistic=1.0, pvalue=0.0)

# %%
ks_2samp(ventes["age"], ventes["categ"])
#statistic value is higher than the critical value, the two distributions are different.
# Out:
# KstestResult(statistic=0.9999650322539448, pvalue=0.0)

# %%
#modalites = ventes[X].unique()
modalites = [ 0.,  1.,  2.]
groupes = []
for m in modalites:
    groupes.append(ventes[ventes[X]==m][Y])

# Propriétés graphiques (pas très importantes)    
medianprops = {'color':"black"}
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}

plt.figure(figsize=(10,6))
plt.boxplot(groupes, labels=modalites, showfliers=False, medianprops=medianprops, 
            vert=False, patch_artist=True, showmeans=True, meanprops=meanprops)
plt.xlabel("Age")
plt.ylabel("Catégorie")
plt.show()

# %%
F, p = f_oneway(groupes[0], groupes[1], groupes[2])

test_pValue(p)
# Out:
# P-val: 0.0
# L'hypothèse nulle est rejeté

# %% [markdown]
#  Alors, il y a une rélation entre catégorie et age
